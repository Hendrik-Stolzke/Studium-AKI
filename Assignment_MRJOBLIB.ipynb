# %% [markdown]
# <a href="https://colab.research.google.com/github/Hendrik-Stolzke/Studium-AKI/blob/main/Assignment_MRJOBLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hadoop MapReduce with Python
# There are two prominent *Python* APIs for interfacing *Hadoop MapReduce* clusters:
#
# ## *Snakebite* for *HDFS* access
# The [Snakebite Lib](https://github.com/spotify/snakebite) allows easy access to *HDFS* file systems:
# ```
# >>> from snakebite.client import Client
# >>> client = Client("localhost", 8020, use_trash=False)
# >>> for x in client.ls(['/']):
# ...     print x
# ```
#
# See [documentation](https://snakebite.readthedocs.io/en/latest/) for details.
#
#
# ## *MRJOB* for *MapReduce* job execution
# The ``mrjob`` lib -> [see docu](https://mrjob.readthedocs.io/en/latest/index.html) is a power full *MapReduce* client for *Python*. Some of the key features are:
#
# * local emulation (single and multi-core) a *Hadoop* cluster for development and debugging
# * simple access, authentication and file transfer to *Hadoop* clusters
# * powerful API for common cloud services, such as AWS or Azure

# %%
#in colab, we need to clone the data from the repo
# !git clone https://github.com/keuperj/DATA.git
# Out:
# Cloning into 'DATA'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 126 (delta 11), reused 39 (delta 11), pack-reused 87 (from 1)
# Receiving objects: 100% (126/126), 185.56 MiB | 10.68 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# Updating files: 100% (86/86), done.

# %% [markdown]
# ### Preparing our environment

# %%
# !pip install mrjob boto3
# Out:
# Collecting mrjob
#   Downloading mrjob-0.7.4-py2.py3-none-any.whl.metadata (7.3 kB)
# Collecting boto3
#   Downloading boto3-1.37.32-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from mrjob) (6.0.2)
# Collecting botocore<1.38.0,>=1.37.32 (from boto3)
#   Downloading botocore-1.37.32-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.32->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.32->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.32->boto3) (1.17.0)
# Downloading mrjob-0.7.4-py2.py3-none-any.whl (439 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.6/439.6 kB 10.6 MB/s eta 0:00:00
# Downloading boto3-1.37.32-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 8.7 MB/s eta 0:00:00
# Downloading botocore-1.37.32-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 58.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: mrjob, jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.32 botocore-1.37.32 jmespath-1.0.1 mrjob-0.7.4 s3transfer-0.11.4

# %% [markdown]
# ## A *MRJOB* Example: WordCount (again)
# Since *Hadoop* works only on file in- and outputs, we do not have usual function based API. We need to pass our code (implementation of *Map* and *Reduce*) as executable *Python* scripts:
#
# * use *Jupyter's* ``%%file`` magic command to write the cell to file
# * create a executable script with ``__main__`` method
# * inherit from the ``MRJob`` class
# * implement ``mapper()`` and ``reducer()`` methods
# * call ``run()`` at start

# %%
# %%file wordcount.py
#this will save this cell as file

from mrjob.job import MRJob

class MRWordCount(MRJob):
    def mapper(self, _, line):
        for word in line.split():
            yield(word, 1)

    def reducer(self, word, counts):
        yield(word, sum(counts))

if __name__ == '__main__':
    MRWordCount.run()
# Out:
# Writing wordcount.py

# %% [markdown]
# ### execute script from cmd
# * ``-r local`` causes local multi-core emulation a *Hadoop* cluster.
# * Input files are cmd arguments
# * define ouput-file (see docs) or use streams: `` > out.txt``

# %%
! python wordcount.py -r local DATA/text1.rst DATA/text2.rst DATA/text3.rst
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for local runner
# Creating temp directory /tmp/wordcount.root.20250411.063000.731616
# Running step 1 of 1...
# job output is in /tmp/wordcount.root.20250411.063000.731616/output
# Streaming final output from /tmp/wordcount.root.20250411.063000.731616/output...
# "breath"	3
# "brown"	7
# "but"	9
# "buzz"	3
# "by"	28
# "cable"	3
# "cajole"	3
# "came"	3
# "charm"	4
# "cheek,"	3
# "chumps"	3
# "close"	3
# "coast"	4
# "conceptions,"	3
# "confound"	3
# "continued"	3
# "control"	3
# "convince"	3
# "copy"	6
# "copy."	3
# "could"	9
# "countless"	3
# "countries"	4
# "country,"	3
# "country."	3
# "created"	4
# "daft"	6
# "darkness"	3
# "day"	3
# "dear"	3
# "decided"	3
# "describe"	3
# "devils"	3
# "devious"	3
# "didn\u2019t"	6
# "dim"	3
# "discotheques"	3
# "do"	3
# "dog."	4
# "dogs"	3
# "down"	3
# "dozen"	3
# "dozy"	3
# "dragged"	3
# "drawing"	3
# "driven"	3
# "drunk"	3
# "dwell"	3
# "earth"	3
# "earth,"	3
# "earthquakes"	3
# "enemy"	3
# "enjoy"	4
# "entire"	4
# "eternity"	3
# "everything"	3
# "exchanged"	3
# "existence"	4
# "existence,"	3
# "experimental"	3
# "experts"	3
# "exquisite"	6
# "eyes,"	3
# "familiar"	3
# "far"	11
# "fax"	6
# "faxed"	3
# "feel"	10
# "few"	9
# "fight"	3
# "first"	3
# "five"	3
# "flax"	3
# "flick"	3
# "flies,"	3
# "floats"	3
# "flock"	3
# "flocked"	3
# "flows"	4
# "fly"	3
# "fog."	3
# "foliage"	3
# "fop"	3
# "for"	25
# "forcing"	3
# "forgot"	3
# "form"	3
# "formed"	3
# "forms"	3
# "fowl"	3
# "fowls."	3
# "fox"	7
# "fox,"	3
# "fox."	9
# "friend"	3
# "friend,"	6
# "from"	16
# "front"	3
# "full"	3
# "fun"	3
# "galvanized"	3
# "game."	3
# "gazed"	3
# "get"	3
# "ghost"	3
# "girl"	3
# "gleams"	3
# "gods"	3
# "grab"	3
# "graced"	3
# "grass"	3
# "greater"	3
# "grow"	3
# "gunboats."	3
# "had"	3
# "happy,"	3
# "has"	7
# "hasn\u2019t"	3
# "have"	3
# "headline"	3
# "hear"	3
# "heart."	4
# "heaven"	3
# "help"	3
# "her"	36
# "her,"	3
# "her."	2
# "her.Far"	1
# "herself"	3
# "hills"	3
# "him."	3
# "his"	3
# "hometown"	3
# "how"	3
# "however"	3
# "if"	3
# "image,"	3
# "impenetrable"	3
# "impress"	3
# "in"	29
# "incapable"	3
# "indescribable"	3
# "infinite"	3
# "initial"	3
# "inner"	3
# "insects"	3
# "insidious"	3
# "into"	12
# "is"	18
# "it"	25
# "its"	9
# "jackets"	3
# "jay,"	3
# "jeopardize"	3
# "jewels."	3
# "jigs"	3
# "jinx"	3
# "job"	3
# "job,"	3
# "jocks"	3
# "-"	3
# "--"	6
# "A"	16
# "Adjusting"	3
# "Alex"	3
# "All"	3
# "Almighty,"	3
# "Alphabet"	3
# "Amazingly"	3
# "And"	3
# "Bawds"	3
# "Baz,"	3
# "Big"	6
# "Blind"	9
# "Blowzy"	3
# "Bookmarksgrove"	4
# "Bookmarksgrove,"	3
# "Brawny"	3
# "Brick"	3
# "Bright"	3
# "But"	3
# "Commas,"	3
# "Consonantia,"	4
# "Copy"	3
# "Cozy"	3
# "Crazy"	3
# "DJs"	4
# "Duden"	4
# "Even"	3
# "Far"	2
# "Few"	3
# "Five"	3
# "Flummoxed"	3
# "Fox"	3
# "Foxy"	3
# "Fredericka"	3
# "God!"	3
# "Grammar."	3
# "Have"	3
# "How"	3
# "I"	44
# "Ipsum"	3
# "Iraq."	3
# "It"	4
# "Italic"	3
# "Jack!\""	3
# "Jack"	3
# "Japan"	3
# "Jim."	6
# "Joaquin"	3
# "July"	3
# "Junk"	3
# "Lane."	3
# "Line"	3
# "Little"	9
# "Longe"	3
# "Lorem"	3
# "MTV"	9
# "Marks"	3
# "Mountains,"	3
# "My"	6
# "O"	3
# "Oh,"	3
# "On"	3
# "One"	3
# "Oxmox"	3
# "Parole"	3
# "Phoenix"	3
# "Pityful"	3
# "Pointing"	3
# "Question"	3
# "Quick"	9
# "Quick,"	3
# "Semantics,"	4
# "Semikoli,"	3
# "Separated"	4
# "Sex-charged"	3
# "She"	3
# "Six"	3
# "Sixty"	3
# "TV"	9
# "Text"	6
# "Text,"	3
# "The"	12
# "Trebek's"	3
# "Two"	3
# "Village"	3
# "Vokalia"	4
# "W."	3
# "Waltz,"	3
# "Watch"	3
# "When"	3
# "When,"	3
# "World"	3
# "Woven"	3
# "Writers"	3
# "Zompyc[1]"	3
# "\"Jeopardy!\","	3
# "\"Now"	3
# "\"and\""	3
# "\u001b[200~Far"	1
# "a"	56
# "about"	3
# "absorb"	3
# "absorbed"	3
# "abused"	3
# "advised"	3
# "again"	3
# "again."	3
# "agency,"	3
# "all"	3
# "all-powerful"	3
# "almost"	3
# "alone,"	4
# "am"	7
# "amazed"	3
# "ambushed"	3
# "among"	6
# "an"	6
# "and"	93
# "and,"	3
# "are"	6
# "around"	9
# "artist"	3
# "as"	9
# "asked"	3
# "at"	7
# "away,"	4
# "ax"	3
# "back"	3
# "bad"	12
# "bag."	3
# "ball"	3
# "be"	9
# "bears"	3
# "because"	3
# "bed."	3
# "been"	6
# "before"	3
# "behind"	4
# "beloved"	3
# "belt"	3
# "big"	9
# "blew"	3
# "blind"	10
# "bliss"	4
# "bliss;"	3
# "blow,"	3
# "blue"	3
# "bold"	3
# "bought"	3
# "bow,"	3
# "box."	3
# "brave"	3
# "skyline"	3
# "small"	7
# "so"	12
# "so,"	3
# "soul"	6
# "soul,"	7
# "souls"	4
# "sphinx"	3
# "splendour"	3
# "spot,"	4
# "spring"	4
# "stalks,"	3
# "steal"	3
# "still"	3
# "stray"	3
# "stream;"	3
# "strength"	3
# "strikes"	3
# "stroke"	3
# "subline"	3
# "sun"	3
# "supplies"	4
# "surface"	3
# "sustains"	3
# "sweet"	4
# "take"	3
# "taken"	4
# "talents."	3
# "tall"	3
# "teems"	3
# "text"	3
# "texts"	3
# "texts."	4
# "than"	3
# "that"	21
# "the"	182
# "their"	10
# "then"	12
# "then,"	3
# "there"	7
# "these"	10
# "they"	10
# "think"	3
# "this"	4
# "thousand"	6
# "thousands"	3
# "throw"	3
# "times"	3
# "to"	24
# "too"	3
# "tranquil"	3
# "trees,"	3
# "trickling"	3
# "turn"	3
# "twenty"	3
# "under"	3
# "universal"	3
# "unknown"	3
# "unorthographic"	3
# "until"	3
# "up"	6
# "upon"	3
# "upper"	3
# "us"	6
# "us,"	3
# "using"	3
# "valley"	3
# "vapour"	3
# "veldt"	3
# "versalia,"	3
# "very"	6
# "vex!"	3
# "vex"	12
# "vex."	3
# "vexing"	3
# "view"	3
# "visions!"	2
# "visions!A"	1
# "vixens"	6
# "vow."	3
# "wafting"	3
# "waltz."	6
# "warm"	3
# "warned"	3
# "was"	13
# "watch"	3
# "waves"	3
# "wax"	3
# "wax."	2
# "wax.The"	1
# "way"	3
# "way."	6
# "weight"	3
# "were"	6
# "whangs"	3
# "whelps."	3
# "when"	9
# "where"	6
# "which"	14
# "while"	3
# "who"	3
# "whole"	4
# "wiki-girl."	3
# "wild"	3
# "will"	3
# "with"	20
# "within"	3
# "wizard\u2019s"	3
# "wolves"	3
# "won"	3
# "wonderful"	4
# "word"	7
# "world"	3
# "would"	9
# "wove"	3
# "woven"	6
# "yet"	3
# "your"	3
# "zany"	3
# "zaps"	3
# "zebra,"	3
# "zebras"	3
# "zephyrs"	9
# "zippers"	3
# "zippy"	3
# "jodhpurs!"	3
# "jog,"	3
# "joke"	3
# "jolt"	3
# "judge."	3
# "jug"	3
# "jukeboxes."	3
# "jumbled"	3
# "jump"	3
# "jump."	3
# "jump;"	3
# "jumping"	3
# "jumps"	4
# "jumpy"	3
# "junk"	3
# "jury"	3
# "just"	3
# "jute"	3
# "killed"	3
# "kvetching"	3
# "language"	4
# "large"	4
# "last"	3
# "lazy"	7
# "leave"	3
# "left"	3
# "letters"	3
# "lie"	3
# "life"	3
# "like"	10
# "line"	3
# "listen."	3
# "little"	3
# "live"	8
# "living"	3
# "long"	3
# "longing,"	3
# "lovably"	3
# "love"	3
# "lovely"	3
# "luck."	3
# "made"	6
# "many"	3
# "me,"	6
# "me:"	3
# "mere"	3
# "meridian"	3
# "met"	3
# "might"	6
# "milk."	3
# "mine."	3
# "mirror"	6
# "mistress,"	3
# "mock"	3
# "moment;"	3
# "mornings"	4
# "mountains,"	4
# "mouth."	3
# "moved"	3
# "movement"	3
# "much"	3
# "my"	56
# "myself"	3
# "name"	3
# "named"	4
# "necessary"	4
# "neglect"	3
# "never"	3
# "no"	6
# "not"	3
# "nothing"	3
# "noticed"	3
# "now."	3
# "nymph,"	3
# "nymphs"	3
# "nymphs."	3
# "ocean."	4
# "of"	98
# "often"	3
# "on"	6
# "opal"	3
# "origin"	3
# "over"	10
# "overspreads"	3
# "own"	6
# "own,"	3
# "packed"	3
# "pager"	3
# "paper"	3
# "paradisematic"	3
# "parsons"	3
# "parts"	3
# "pick:"	3
# "picked"	3
# "pig,"	3
# "place"	4
# "plaid"	3
# "plants"	3
# "pled."	3
# "possession"	4
# "power,"	3
# "presence"	3
# "present"	3
# "prog."	3
# "projects"	3
# "provide"	3
# "put"	3
# "pyjamas"	3
# "quack!"	3
# "quack"	3
# "quack."	3
# "quacking"	3
# "quart"	3
# "quartz,"	3
# "quartz."	3
# "question"	3
# "questions"	3
# "quick"	9
# "quick,"	4
# "quick-jived"	3
# "quickly"	12
# "quietly"	3
# "quips"	3
# "quit."	3
# "quiver"	3
# "quiz!"	3
# "quiz"	24
# "quiz."	6
# "ran"	3
# "reached"	3
# "red"	3
# "regelialia."	4
# "rethoric"	3
# "return"	3
# "rewritten"	3
# "rewritten,"	3
# "right"	4
# "river"	4
# "road,"	3
# "roasted"	3
# "safe"	3
# "said"	3
# "sanctuary,"	3
# "seem"	3
# "seized"	3
# "sense"	3
# "sentences"	3
# "serenity"	4
# "seven"	3
# "she"	18
# "should"	6
# "show."	3
# "silk"	3
# "single"	3
# "sink"	3
# "six"	9
# Removing temp directory /tmp/wordcount.root.20250411.063000.731616...

# %% [markdown]
# ## Execution on AWS EMR
# AWS EMR is a clound formation service which allows you to create *Hadoop*, *Spark* and other data analytics clusters with a few clicks.
#
# **NOTE**: we are not endorsing AWS specifically, other cloud service providers have similar offers

# %% [markdown]
# ### Case 1: create cluster on the fly
# We create a cluster just for a single job:
# * simple solution for large jobs that run only once (or only at sparse points in time)
# * this approach cause a lot of over head: not suitable for small and frequent jobs
#
# First, we need a config file for the connection to EMR:
# **fill in YOUR AWS credentials**

# %%
# %%file mrjob.conf
# runners:
#   emr:
#     aws_access_key_id: AKIA4KIF2TSEWFSWC4VT
#     aws_secret_access_key: BA5oZyU3yikk5sENw7xPubWZzFNhq2eiVfZqihQP
#     instance_type: m5.xlarge
#     num_core_instances: 2
#     region: eu-west-1
# Out:
# Overwriting mrjob.conf

# %%
! python wordcount.py -r emr --bootstrap-mrjob DATA/text1.rst DATA/text2.rst -c mrjob.conf
# Out:
# Using s3://mrjob-757042689da50525/tmp/ as our temp dir on S3
# Creating temp directory /tmp/wordcount.root.20250411.063227.120206
# uploading working dir files to s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.063227.120206/files/wd...
# Copying other local files to s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.063227.120206/files/
# Can't access IAM API, trying default instance profile: EMR_EC2_DefaultRole
# Can't access IAM API, trying default service role: EMR_DefaultRole
# Created new cluster j-4U1XKBE6GAJ5
# Added EMR tags to cluster j-4U1XKBE6GAJ5: __mrjob_label=wordcount, __mrjob_owner=root, __mrjob_version=0.7.4
# Waiting for Step 1 of 1 (s-02416526OS0GFTLEHNQ) to complete...
#   PENDING (cluster is STARTING: Provisioning Amazon EC2 capacity)
#   PENDING (cluster is STARTING: Provisioning Amazon EC2 capacity)
#   PENDING (cluster is STARTING: Provisioning Amazon EC2 capacity)
#   PENDING (cluster is STARTING: Provisioning Amazon EC2 capacity)
#   PENDING (cluster is STARTING: Provisioning Amazon EC2 capacity)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   master node is ec2-34-253-187-201.eu-west-1.compute.amazonaws.com
#   RUNNING for 0:00:25
#   RUNNING for 0:00:56
#   COMPLETED
# Attempting to fetch counters from logs...
# Waiting for cluster (j-4U1XKBE6GAJ5) to terminate...
#   TERMINATING
#   TERMINATING
#   TERMINATED
# Looking for step log in s3://mrjob-757042689da50525/tmp/logs/j-4U1XKBE6GAJ5/steps/s-02416526OS0GFTLEHNQ...
#   Parsing step log: s3://mrjob-757042689da50525/tmp/logs/j-4U1XKBE6GAJ5/steps/s-02416526OS0GFTLEHNQ/syslog.gz
# Counters: 60
# 	File Input Format Counters
# 		Bytes Read=27487
# 	File Output Format Counters
# 		Bytes Written=3958
# 	File System Counters
# 		FILE: Number of bytes read=4887
# 		FILE: Number of bytes written=2914319
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1233
# 		HDFS: Number of bytes read erasure-coded=0
# 		HDFS: Number of bytes written=0
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=0
# 		S3: Number of bytes read=27487
# 		S3: Number of bytes written=3958
# 		S3: Number of large read operations=0
# 		S3: Number of read operations=0
# 		S3: Number of write operations=0
# 	Job Counters
# 		Data-local map tasks=9
# 		Killed reduce tasks=1
# 		Launched map tasks=9
# 		Launched reduce tasks=3
# 		Total megabyte-milliseconds taken by all map tasks=300850176
# 		Total megabyte-milliseconds taken by all reduce tasks=108349440
# 		Total time spent by all map tasks (ms)=97933
# 		Total time spent by all maps in occupied slots (ms)=300850176
# 		Total time spent by all reduce tasks (ms)=17635
# 		Total time spent by all reduces in occupied slots (ms)=108349440
# 		Total vcore-milliseconds taken by all map tasks=97933
# 		Total vcore-milliseconds taken by all reduce tasks=17635
# 	Map-Reduce Framework
# 		CPU time spent (ms)=23500
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=3176
# 		Input split bytes=1233
# 		Map input records=2
# 		Map output bytes=18952
# 		Map output materialized bytes=5681
# 		Map output records=1998
# 		Merged Map outputs=27
# 		Peak Map Physical memory (bytes)=626163712
# 		Peak Map Virtual memory (bytes)=4504092672
# 		Peak Reduce Physical memory (bytes)=541904896
# 		Peak Reduce Virtual memory (bytes)=7139659776
# 		Physical memory (bytes) snapshot=6702338048
# 		Reduce input groups=370
# 		Reduce input records=1998
# 		Reduce output records=370
# 		Reduce shuffle bytes=5681
# 		Shuffled Maps =27
# 		Spilled Records=3996
# 		Total committed heap usage (bytes)=6521618432
# 		Virtual memory (bytes) snapshot=61573668864
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# job output is in s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.063227.120206/output/
# Streaming final output from s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.063227.120206/output/...
# "--"	6
# "Alphabet"	3
# "Blind"	9
# "Bookmarksgrove"	4
# "Consonantia,"	4
# "Copy"	3
# "God!"	3
# "It"	4
# "Longe"	3
# "Marks"	3
# "On"	3
# "Separated"	4
# "She"	3
# "Village"	3
# "Vokalia"	4
# "When"	3
# "When,"	3
# "about"	3
# "again"	3
# "almost"	3
# "ambushed"	3
# "among"	6
# "an"	6
# "and,"	3
# "are"	6
# "at"	7
# "belt"	3
# "blind"	10
# "buzz"	3
# "by"	13
# "cheek,"	3
# "control"	3
# "convince"	3
# "countries"	4
# "country,"	3
# "day"	3
# "devious"	3
# "drunk"	3
# "dwell"	3
# "existence"	4
# "eyes,"	3
# "familiar"	3
# "for"	13
# "forms"	3
# "friend,"	6
# "full"	3
# "gleams"	3
# "grow"	3
# "happy,"	3
# "have"	3
# "heart."	4
# "her,"	3
# "herself"	3
# "his"	3
# "however"	3
# "if"	3
# "impenetrable"	3
# "impress"	3
# "indescribable"	3
# "its"	9
# "language"	4
# "live"	8
# "living"	3
# "long"	3
# "longing,"	3
# "love"	3
# "lovely"	3
# "mountains,"	4
# "mouth."	3
# "much"	3
# "name"	3
# "neglect"	3
# "noticed"	3
# "ocean."	4
# "of"	89
# "over"	3
# "own,"	3
# "paper"	3
# "paradisematic"	3
# "parts"	3
# "possession"	4
# "projects"	3
# "put"	3
# "ran"	3
# "regelialia."	4
# "rewritten,"	3
# "right"	4
# "roasted"	3
# "said"	3
# "sanctuary,"	3
# "seem"	3
# "sense"	3
# "serenity"	4
# "seven"	3
# "should"	6
# "skyline"	3
# "so,"	3
# "souls"	4
# "splendour"	3
# "stray"	3
# "stroke"	3
# "subline"	3
# "sun"	3
# "supplies"	4
# "surface"	3
# "sustains"	3
# "talents."	3
# "tall"	3
# "teems"	3
# "text"	3
# "the"	155
# "there"	7
# "think"	3
# "thousands"	3
# "trees,"	3
# "under"	3
# "upon"	3
# "us,"	3
# "vapour"	3
# "warned"	3
# "were"	3
# "where"	6
# "wild"	3
# "with"	20
# "within"	3
# "wonderful"	4
# "word"	7
# "Almighty,"	3
# "Big"	3
# "Bookmarksgrove,"	3
# "Commas,"	3
# "Duden"	4
# "Grammar."	3
# "I"	44
# "Ipsum"	3
# "Italic"	3
# "Lane."	3
# "Lorem"	3
# "O"	3
# "Pityful"	3
# "Semantics,"	4
# "Semikoli,"	3
# "Text"	6
# "Text,"	3
# "The"	6
# "Writers"	3
# "\"and\""	3
# "\u001b[200~Far"	1
# "a"	40
# "absorb"	3
# "absorbed"	3
# "again."	3
# "all"	3
# "all-powerful"	3
# "and"	78
# "artist"	3
# "bad"	3
# "be"	9
# "bears"	3
# "because"	3
# "behind"	4
# "bliss;"	3
# "breath"	3
# "but"	9
# "came"	3
# "close"	3
# "conceptions,"	3
# "continued"	3
# "copy."	3
# "countless"	3
# "darkness"	3
# "dear"	3
# "didn\u2019t"	6
# "do"	3
# "dragged"	3
# "drawing"	3
# "enjoy"	4
# "eternity"	3
# "far"	11
# "feel"	10
# "few"	6
# "first"	3
# "floats"	3
# "flows"	4
# "fly"	3
# "form"	3
# "formed"	3
# "from"	10
# "had"	3
# "has"	7
# "headline"	3
# "her"	36
# "hills"	3
# "hometown"	3
# "incapable"	3
# "infinite"	3
# "inner"	3
# "insidious"	3
# "into"	12
# "is"	15
# "last"	3
# "leave"	3
# "left"	3
# "like"	10
# "line"	3
# "me:"	3
# "might"	3
# "mine."	3
# "mirror"	6
# "not"	3
# "often"	3
# "origin"	3
# "own"	6
# "rewritten"	3
# "river"	4
# "safe"	3
# "small"	7
# "so"	12
# "soul"	6
# "soul,"	7
# "spot,"	4
# "spring"	4
# "stalks,"	3
# "steal"	3
# "still"	3
# "strikes"	3
# "sweet"	4
# "take"	3
# "taken"	4
# "than"	3
# "that"	21
# "their"	10
# "these"	10
# "they"	10
# "throw"	3
# "times"	3
# "turn"	3
# "us"	6
# "warm"	3
# "was"	10
# "way"	3
# "weight"	3
# "which"	14
# "while"	3
# "who"	3
# "whole"	4
# "world"	3
# "would"	9
# "your"	3
# "A"	7
# "And"	3
# "But"	3
# "Even"	3
# "Far"	2
# "Line"	3
# "Little"	9
# "Mountains,"	3
# "Oh,"	3
# "One"	3
# "Oxmox"	3
# "Parole"	3
# "Pointing"	3
# "Question"	3
# "World"	3
# "abused"	3
# "advised"	3
# "agency,"	3
# "alone,"	4
# "am"	7
# "around"	9
# "as"	9
# "away,"	4
# "back"	3
# "been"	6
# "beloved"	3
# "bliss"	4
# "charm"	4
# "coast"	4
# "copy"	6
# "could"	9
# "country."	3
# "created"	4
# "decided"	3
# "describe"	3
# "down"	3
# "earth"	3
# "earth,"	3
# "entire"	4
# "everything"	3
# "existence,"	3
# "exquisite"	3
# "flies,"	3
# "foliage"	3
# "friend"	3
# "grass"	3
# "greater"	3
# "hasn\u2019t"	3
# "hear"	3
# "heaven"	3
# "her."	2
# "her.Far"	1
# "image,"	3
# "in"	23
# "initial"	3
# "insects"	3
# "it"	25
# "large"	4
# "lie"	3
# "life"	3
# "listen."	3
# "little"	3
# "made"	6
# "me,"	6
# "mere"	3
# "meridian"	3
# "met"	3
# "mistress,"	3
# "moment;"	3
# "mornings"	4
# "my"	38
# "myself"	3
# "named"	4
# "necessary"	4
# "never"	3
# "no"	3
# "nothing"	3
# "now."	3
# "on"	6
# "overspreads"	3
# "packed"	3
# "place"	4
# "plants"	3
# "power,"	3
# "presence"	3
# "present"	3
# "question"	3
# "reached"	3
# "rethoric"	3
# "return"	3
# "road,"	3
# "sentences"	3
# "she"	15
# "single"	3
# "sink"	3
# "stream;"	3
# "strength"	3
# "texts"	3
# "texts."	4
# "then"	12
# "then,"	3
# "this"	4
# "thousand"	6
# "to"	15
# "too"	3
# "tranquil"	3
# "trickling"	3
# "universal"	3
# "unknown"	3
# "unorthographic"	3
# "until"	3
# "upper"	3
# "using"	3
# "valley"	3
# "versalia,"	3
# "view"	3
# "visions!"	2
# "visions!A"	1
# "way."	6
# "when"	6
# "yet"	3
# Removing s3 temp directory s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.063227.120206/...
# Removing temp directory /tmp/wordcount.root.20250411.063227.120206...
# Removing log files in s3://mrjob-757042689da50525/tmp/logs/j-4U1XKBE6GAJ5/...
# Terminating cluster: j-4U1XKBE6GAJ5

# %% [markdown]
# ### Case 2: connect to existing cluster

# %%
# %%file mrjob_cluster.conf
# runners:
#   emr:
#     aws_access_key_id: AKIA4KIF2TSEWFSWC4VT
#     aws_secret_access_key: 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
#     region: eu-west-1
# Out:
# Overwriting mrjob_cluster.conf

# %% [markdown]
# We need the **ID** of the cluster we want to connect to.

# %%
! python wordcount.py -r emr --cluster-id=j-23NVQRXYUPUWK DATA/text1.rst DATA/text2.rst -c mrjob_cluster.conf
# Out:
# Using s3://mrjob-757042689da50525/tmp/ as our temp dir on S3
# Creating temp directory /tmp/wordcount.root.20250411.064246.381206
# uploading working dir files to s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.064246.381206/files/wd...
# Copying other local files to s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.064246.381206/files/
# Adding our job to existing cluster j-23NVQRXYUPUWK
#   master node is ec2-34-242-59-145.eu-west-1.compute.amazonaws.com
# Waiting for Step 1 of 1 (s-05740712BDU5N1EKKH44) to complete...
#   PENDING (cluster is RUNNING: Running step)
#   RUNNING for 0:00:19
#   COMPLETED
# Attempting to fetch counters from logs...
# Waiting 10 minutes for logs to transfer to S3... (ctrl-c to skip)
#
# To fetch logs immediately next time, set up SSH. See:
# https://pythonhosted.org/mrjob/guides/emr-quickstart.html#configuring-ssh-credentials
#
# Looking for step log in s3://aws-logs-846657657993-eu-west-1/elasticmapreduce/j-23NVQRXYUPUWK/steps/s-05740712BDU5N1EKKH44...
#   Parsing step log: s3://aws-logs-846657657993-eu-west-1/elasticmapreduce/j-23NVQRXYUPUWK/steps/s-05740712BDU5N1EKKH44/syslog.gz
# Counters: 60
# 	File Input Format Counters
# 		Bytes Read=49371
# 	File Output Format Counters
# 		Bytes Written=3958
# 	File System Counters
# 		FILE: Number of bytes read=5223
# 		FILE: Number of bytes written=7923693
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2329
# 		HDFS: Number of bytes read erasure-coded=0
# 		HDFS: Number of bytes written=0
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=17
# 		HDFS: Number of write operations=0
# 		S3: Number of bytes read=49371
# 		S3: Number of bytes written=3958
# 		S3: Number of large read operations=0
# 		S3: Number of read operations=0
# 		S3: Number of write operations=0
# 	Job Counters
# 		Data-local map tasks=17
# 		Killed map tasks=1
# 		Launched map tasks=17
# 		Launched reduce tasks=7
# 		Total megabyte-milliseconds taken by all map tasks=600142848
# 		Total megabyte-milliseconds taken by all reduce tasks=272941056
# 		Total time spent by all map tasks (ms)=195359
# 		Total time spent by all maps in occupied slots (ms)=600142848
# 		Total time spent by all reduce tasks (ms)=44424
# 		Total time spent by all reduces in occupied slots (ms)=272941056
# 		Total vcore-milliseconds taken by all map tasks=195359
# 		Total vcore-milliseconds taken by all reduce tasks=44424
# 	Map-Reduce Framework
# 		CPU time spent (ms)=52060
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=1765
# 		Input split bytes=2329
# 		Map input records=2
# 		Map output bytes=18952
# 		Map output materialized bytes=7475
# 		Map output records=1998
# 		Merged Map outputs=119
# 		Peak Map Physical memory (bytes)=668774400
# 		Peak Map Virtual memory (bytes)=4551004160
# 		Peak Reduce Physical memory (bytes)=413237248
# 		Peak Reduce Virtual memory (bytes)=7239917568
# 		Physical memory (bytes) snapshot=12801138688
# 		Reduce input groups=370
# 		Reduce input records=1998
# 		Reduce output records=370
# 		Reduce shuffle bytes=7475
# 		Shuffled Maps =119
# 		Spilled Records=3996
# 		Total committed heap usage (bytes)=10653532160
# 		Virtual memory (bytes) snapshot=127770992640
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# job output is in s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.064246.381206/output/
# Streaming final output from s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.064246.381206/output/...
# "And"	3
# "Lane."	3
# "Oxmox"	3
# "The"	6
# "\u001b[200~Far"	1
# "a"	40
# "abused"	3
# "advised"	3
# "again."	3
# "almost"	3
# "am"	7
# "are"	6
# "at"	7
# "away,"	4
# "bliss"	4
# "breath"	3
# "coast"	4
# "conceptions,"	3
# "country."	3
# "darkness"	3
# "drawing"	3
# "far"	11
# "for"	13
# "form"	3
# "friend,"	6
# "full"	3
# "greater"	3
# "headline"	3
# "initial"	3
# "inner"	3
# "live"	8
# "mere"	3
# "met"	3
# "moment;"	3
# "now."	3
# "of"	89
# "origin"	3
# "own,"	3
# "regelialia."	4
# "said"	3
# "sentences"	3
# "so"	12
# "strength"	3
# "subline"	3
# "surface"	3
# "texts"	3
# "texts."	4
# "this"	4
# "thousand"	6
# "thousands"	3
# "under"	3
# "upon"	3
# "us,"	3
# "using"	3
# "versalia,"	3
# "was"	10
# "where"	6
# "wild"	3
# "with"	20
# "within"	3
# "world"	3
# "It"	4
# "Longe"	3
# "Mountains,"	3
# "Parole"	3
# "She"	3
# "Vokalia"	4
# "When"	3
# "World"	3
# "all-powerful"	3
# "artist"	3
# "blind"	10
# "but"	9
# "convince"	3
# "country,"	3
# "earth"	3
# "floats"	3
# "flows"	4
# "fly"	3
# "grass"	3
# "has"	7
# "heart."	4
# "her.Far"	1
# "hills"	3
# "impenetrable"	3
# "incapable"	3
# "infinite"	3
# "large"	4
# "leave"	3
# "listen."	3
# "little"	3
# "love"	3
# "me,"	6
# "me:"	3
# "mouth."	3
# "ocean."	4
# "often"	3
# "overspreads"	3
# "put"	3
# "seem"	3
# "seven"	3
# "should"	6
# "skyline"	3
# "so,"	3
# "souls"	4
# "splendour"	3
# "spring"	4
# "stalks,"	3
# "steal"	3
# "stream;"	3
# "sun"	3
# "taken"	4
# "text"	3
# "that"	21
# "these"	10
# "trickling"	3
# "unorthographic"	3
# "A"	7
# "Bookmarksgrove"	4
# "Ipsum"	3
# "Little"	9
# "O"	3
# "Oh,"	3
# "On"	3
# "Semantics,"	4
# "absorb"	3
# "all"	3
# "around"	9
# "continued"	3
# "could"	9
# "day"	3
# "dragged"	3
# "drunk"	3
# "dwell"	3
# "feel"	10
# "few"	6
# "first"	3
# "friend"	3
# "hasn\u2019t"	3
# "if"	3
# "into"	12
# "it"	25
# "living"	3
# "longing,"	3
# "lovely"	3
# "mistress,"	3
# "named"	4
# "neglect"	3
# "never"	3
# "nothing"	3
# "own"	6
# "paper"	3
# "presence"	3
# "reached"	3
# "rewritten"	3
# "right"	4
# "sink"	3
# "supplies"	4
# "then,"	3
# "to"	15
# "until"	3
# "us"	6
# "vapour"	3
# "visions!A"	1
# "weight"	3
# "who"	3
# "yet"	3
# "Alphabet"	3
# "Bookmarksgrove,"	3
# "Commas,"	3
# "Line"	3
# "Lorem"	3
# "Marks"	3
# "One"	3
# "Pityful"	3
# "absorbed"	3
# "alone,"	4
# "among"	6
# "an"	6
# "and"	78
# "and,"	3
# "beloved"	3
# "belt"	3
# "by"	13
# "came"	3
# "describe"	3
# "eternity"	3
# "flies,"	3
# "foliage"	3
# "his"	3
# "however"	3
# "image,"	3
# "impress"	3
# "insidious"	3
# "its"	9
# "left"	3
# "life"	3
# "myself"	3
# "on"	6
# "rethoric"	3
# "rewritten,"	3
# "river"	4
# "sanctuary,"	3
# "sense"	3
# "serenity"	4
# "spot,"	4
# "stroke"	3
# "sweet"	4
# "the"	155
# "they"	10
# "tranquil"	3
# "unknown"	3
# "upper"	3
# "when"	6
# "which"	14
# "Blind"	9
# "Copy"	3
# "Duden"	4
# "Far"	2
# "Italic"	3
# "Separated"	4
# "When,"	3
# "\"and\""	3
# "again"	3
# "as"	9
# "back"	3
# "bad"	3
# "control"	3
# "copy."	3
# "countries"	4
# "dear"	3
# "earth,"	3
# "enjoy"	4
# "entire"	4
# "existence"	4
# "exquisite"	3
# "formed"	3
# "forms"	3
# "gleams"	3
# "grow"	3
# "her."	2
# "hometown"	3
# "made"	6
# "meridian"	3
# "mirror"	6
# "mornings"	4
# "my"	38
# "necessary"	4
# "no"	3
# "over"	3
# "packed"	3
# "place"	4
# "plants"	3
# "power,"	3
# "projects"	3
# "ran"	3
# "road,"	3
# "safe"	3
# "she"	15
# "sustains"	3
# "take"	3
# "than"	3
# "times"	3
# "turn"	3
# "view"	3
# "way"	3
# "would"	9
# "--"	6
# "Big"	3
# "But"	3
# "Consonantia,"	4
# "God!"	3
# "Grammar."	3
# "I"	44
# "Semikoli,"	3
# "Text,"	3
# "Writers"	3
# "about"	3
# "ambushed"	3
# "buzz"	3
# "charm"	4
# "countless"	3
# "do"	3
# "down"	3
# "eyes,"	3
# "from"	10
# "had"	3
# "happy,"	3
# "heaven"	3
# "her,"	3
# "in"	23
# "indescribable"	3
# "last"	3
# "line"	3
# "long"	3
# "might"	3
# "much"	3
# "name"	3
# "not"	3
# "paradisematic"	3
# "parts"	3
# "return"	3
# "roasted"	3
# "single"	3
# "soul,"	7
# "still"	3
# "strikes"	3
# "teems"	3
# "then"	12
# "think"	3
# "too"	3
# "trees,"	3
# "universal"	3
# "visions!"	2
# "warm"	3
# "way."	6
# "were"	3
# "while"	3
# "wonderful"	4
# "Almighty,"	3
# "Even"	3
# "Pointing"	3
# "Question"	3
# "Text"	6
# "Village"	3
# "agency,"	3
# "be"	9
# "bears"	3
# "because"	3
# "been"	6
# "behind"	4
# "bliss;"	3
# "cheek,"	3
# "close"	3
# "copy"	6
# "created"	4
# "decided"	3
# "devious"	3
# "didn\u2019t"	6
# "everything"	3
# "existence,"	3
# "familiar"	3
# "have"	3
# "hear"	3
# "her"	36
# "herself"	3
# "insects"	3
# "is"	15
# "language"	4
# "lie"	3
# "like"	10
# "mine."	3
# "mountains,"	4
# "noticed"	3
# "possession"	4
# "present"	3
# "question"	3
# "small"	7
# "soul"	6
# "stray"	3
# "talents."	3
# "tall"	3
# "their"	10
# "there"	7
# "throw"	3
# "valley"	3
# "warned"	3
# "whole"	4
# "word"	7
# "your"	3
# Removing s3 temp directory s3://mrjob-757042689da50525/tmp/wordcount.root.20250411.064246.381206/...
# Removing temp directory /tmp/wordcount.root.20250411.064246.381206...

# %% [markdown]
# ## Exercise
# Use  *mrjob*  to  compute  employee  **top  annual  salaries** and  **gross pay** in the *CSV* table ``Baltimore_City_employee_Salaries_FY2014.csv``.
#
# * use  ``import csv`` to read the data -> [API docs](https://docs.python.org/3/library/csv.html)
# * use ``yield`` to return *producers* from *map* and *reduce* functions
# * return top entries in both categories

# %%
# %%file MRTopSalariesfile.py
from mrjob.job import MRJob
import csv

class MRTopSalaries(MRJob):
    def mapper(self, _, line):
        row = csv.reader([line], delimiter=',').__next__()
        try:
            if row[0].strip() == 'Name':
                return
            name = row[0].strip()
            annual_salary = float(row[5].strip().replace('$', '').replace(',', ''))
            gross_pay = float(row[6].strip().replace('$', '').replace(',', ''))
            yield 'annual', (name, annual_salary)
            yield 'gross', (name, gross_pay)
        except:
            pass

    def reducer(self, key, values):
        top_10 = sorted(values, key=lambda x: x[1], reverse=True)[:10]
        for name, amount in top_10:
            yield key, (name, amount)

if __name__ == '__main__':
    MRTopSalaries.run()
# Out:
# Writing MRTopSalariesfile.py

# %%
! python MRTopSalariesfile.py -r local /content/DATA/Baltimore_City_Employee_Salaries_FY2014.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for local runner
# Creating temp directory /tmp/MRTopSalariesfile.root.20250411.081317.218283
# Running step 1 of 1...
# job output is in /tmp/MRTopSalariesfile.root.20250411.081317.218283/output
# Streaming final output from /tmp/MRTopSalariesfile.root.20250411.081317.218283/output...
# "gross"	["Bernstein,Gregg L", 238772.04]
# "gross"	["Batts,Anthony W", 193653.69]
# "gross"	["Black,Harry E", 188328.5]
# "gross"	["Charles,Ronnie E", 185741.81]
# "gross"	["Nalewajko Jr,Stephen C", 176141.33]
# "gross"	["Marcus Sr,Albert M", 173876.84]
# "gross"	["Stokes,Charline B", 166442.42]
# "gross"	["Harris Jr,William", 165892.21]
# "gross"	["Makanjuola,Rafiu T", 165270.01]
# "gross"	["Cheelsman III,Charles H", 165108.5]
# "annual"	["Bernstein,Gregg L", 238772.0]
# "annual"	["Charles,Ronnie E", 200000.0]
# "annual"	["Batts,Anthony W", 193800.0]
# "annual"	["Black,Harry E", 190000.0]
# "annual"	["Swift,Michael", 187200.0]
# "annual"	["Parthemos,Kaliope", 172000.0]
# "annual"	["Ford,Niles R", 165000.0]
# "annual"	["Rawlings-Blake,Stephanie C", 163365.0]
# "annual"	["Chow,Rudolph S", 163200.0]
# "annual"	["Nilson,George A", 163200.0]
# Removing temp directory /tmp/MRTopSalariesfile.root.20250411.081317.218283...
